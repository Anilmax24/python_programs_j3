# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statement
# 2. if statements
# 3. elif  statements
# 4. else statements
# 5. nested statements
#  ```python -if
#  if (condtion):#if condtion true inside statements are running
#      statements
#      statement....
#      ```
#      ````python-if ,else
# if (condition):#condition true inside statements are running
#    statemets1
#     statements2...
#     else:#if conditon fails its went to else statemen and inside statements
#         statement1
#         statement2.....n
# ```python - if ,elif,else
# if (condtion):
#     statements
# elif(condition):
#     statement
# elif(condition):
#      statement
# else:
#     statements
# ```

# %%
#write a program to find the given number is even number?
number=int(input("enternumber here:"))

if (number%2==0):
    print(number,"is even number")
# Out:
# enternumber here: 98
# 98 is even number

# %%
#write aprogram to find the given number is even number or odd number ?
num=int(input("please enter number here:"))
if(num%2==1):
    print(num,"is odd number")
else:
    print(num,"is even number")
# Out:
# please enter number here: 789
# 789 is odd number

# %%
#write a porgram to find the given number is positive or negitive or zero?
n=int(input("please enter number here:"))
if (n>0):
      print(n,"is positive number")
elif(n<0):
     print(n,"is negitive number")
else:
    print(n,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
#write a porgram to find the largest number from three number?
v1=int(input("enter first number here :"))
v2=int(input("enter second number here :"))
v3=int(input("enter thrid  number here :"))
if (v1>=v2 and v1>=v3):
    print(v1,"is largest number ")
elif(v2>=v1 and v2>=v3 ):
    print(v2,"is the largestbnumber")
else:
   print(v3,"is the largest number ")
# Out:
# enter first number here : 100
# enter second number here : 100
# enter thrid  number here : 90
# 100 is largest number

# %%
"""
write  a program to find the grades based on student marks
1.if marks in between 80 to 100 -A grade
2.if marks in between 60 to 79 -B grade
3.if marks in between 40 to 59-C grade
4.if marks in between 25 to 39 -D grade
5.if marks in between 0 to 24-Fail grade
6.if other than above marks output is -please enter correct marks
"""
marks=int(input("enter student marks here:"))
if(marks>=80 and marks<=100):
   print(marks ,"A grade")
elif(marks>=60 and marks<=79):
     print(marks ,"B grade")
elif(marks>=40 and marks<=59):
     print(marks ,"C grade")
elif(marks>=25 and marks<=39):
     print(marks ,"D grade")
elif(marks>=0 and marks<=24):
    print(marks ,"is fail")
else:
    print("please enter correct marks")
# Out:
# enter student marks here: 99
# 99 A grade

# %%
#write a porgram to valid longin credentials using conditional statements
username=str(input("please enter username here:"))
if (username=="siva@123"):
    print("username is valid")
    password=str(input("please enter password here:"))
   if (password=="sivaji@12345"):
       print("user crednetilas successfully valid")
    else:
        print ("password is invalid")
else:
   print("username is invalid")
# Out:
#   File <string>:6
#     if (password=="sivaji@12345"):
#                                   ^
# IndentationError: unindent does not match any outer indentation level
